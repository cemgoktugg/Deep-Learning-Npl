# %% [markdown]
# <a href="https://colab.research.google.com/github/cemgoktugg/Deep-Learning-Npl/blob/main/image_data_augmentation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True) 
"""drive.mount('drive')
# %cd drive/My Drive/images
# !ls"""
# Out:
# Mounted at /content/drive
# "drive.mount('drive')\n%cd drive/My Drive/images\n!ls"

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img, array_to_img
import os 

os.chdir = img_path = '/content/drive/My Drive/images/t1_fl3d_sag_p4_iso_1.0_165.png'
target_img = load_img(img_path)
target_img = np.array(target_img)
x = target_img.reshape((1,) + target_img.shape)

# %%
data_generator = ImageDataGenerator(rotation_range=90)  
generator = data_generator.flow(x, batch_size=1)  
batches = next(generator)  
get_img = array_to_img(batches[0])

plt.show()

# %%
def show_gen_img(data_generator):
    generator = data_generator.flow(x, batch_size=1)
    plt.figure(figsize=(17,8))
    for i in range(4):
        batches = next(generator)
        gen_img = array_to_img(batches[0])
        plt.subplot(1, 4, i+1)
        plt.imshow(gen_img)
    plt.show()

# %%
data_generator = ImageDataGenerator(brightness_range=[0.3, 2.0])  
show_gen_img(data_generator)

# %%
data_generator = ImageDataGenerator(height_shift_range=0.2)
show_gen_img(data_generator)

# %%
data_generator = ImageDataGenerator(zoom_range=[0.3, 1.5])   
show_gen_img(data_generator)

# %%
data_generator = ImageDataGenerator(shear_range=20)  
show_gen_img(data_generator)

# %%
data_generator = ImageDataGenerator(width_shift_range=0.2)
show_gen_img(data_generator)

# %%
data_generator = ImageDataGenerator(height_shift_range=0.2)
show_gen_img(data_generator)

# %%
import os

save_dir = '/content/drive/My Drive/images/yeni'
os.makedirs(save_dir, exist_ok=True)

data_generator = ImageDataGenerator(rotation_range=90)  
generator = data_generator.flow(x, batch_size=1, save_to_dir=save_dir, save_prefix='t1_fl3d_sag_p4_iso_1.0_165', save_format='png')
batches = next(generator)
